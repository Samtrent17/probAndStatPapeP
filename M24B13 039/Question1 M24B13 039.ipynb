# %% [markdown]
# ### NANGOLI SAMUEL M24B13/039

# %%
#using the Q1_hotel_booking.csv file
#import necessary libraries
import pandas as pd
import numpy as np
import scipy
import matplotlib as plt

# %%
#reading the dataset from the folder
sam= pd.read_csv('Q1_hotel_bookings.csv')

# %%
sam.info
# Out:
# <bound method DataFrame.info of                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
#loading the dataset
sam
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
sam.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %% [markdown]
# ## Question 1
# ### Distribution of any one categorical variable including the visuals and statistics

# %%
#distribution of any one categorical variables including the visuals and statistics
#using a graph to show the distribution of categorical variables including the visuals and statistics.
sam.hist(['A graph show the adults in the hotel'])
plt.figure(figsize=(20,10))
plt.xlabel('number of adults')
plt.ylabel('number of rooms occured')
plt.title('A graph showing the number of adults occupying the hotel')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 3
#       1 #distribution of any one categorical variables including the visuals and statistics
#       2 #using a graph to show the distribution of categorical variables including the visuals and statistics.
# ----> 3 sam.hist(['A graph show the adults in the hotel'])
#       4 plt.figure(figsize=(20,10))
#       5 plt.xlabel('number of adults')
#
# File c:\Users\STUDENT.DESKTOP-BAS9K8N\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\plotting\_core.py:251, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     164 """
#     165 Make a histogram of the DataFrame's columns.
#     166
#    (...)
#     248     >>> hist = df.hist(bins=3)
#     249 """
#     250 plot_backend = _get_plot_backend(backend)
# ...
